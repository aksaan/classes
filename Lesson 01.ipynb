# %%
a = 1
b = 2

# %%
def main():
    name = input()
    print(f'Hello {name}!')

main()
# Out:
# Anna
# Hello Anna!

# %%
class A:
    def __init__(self, *args, **kwargs):
        pass

    def f(self):
        return 'f_A'

    def g(self):
        return 'g_A'

    def __repr__(self) -> str:
        return 'instance of A'

# %%
a = A()

# %%
a
# Out:
# instance of A

# %%
class B:
    def f(self):
        return 'f_B'

# %%
class C(A, B):
    pass

# %%
c = C()

# %%
c
# Out:
# instance of A

# %%
b = B()

# %%
b.g()
# Out:
# 'g_A'

# %%
del list

# %%
lst = list()

# %%
lst.append(0)

# %%
lst
# Out:
# [0]

# %%
tuple(), set(), dict()
# Out:
# ((), set(), {})

# %% [markdown]
# **Домашнее задание**
#
# - [ ] начать читать [основы Питона](https://academy.yandex.ru/handbook/python)
# - [ ] ознакомиться с сайтом https://leetcode.com/
# - [ ] придумать простые задачки на визуализацию, статистику (pandas, matplotlib)
# - [ ] начать продумывать легкий проект
# - [ ] начать продумывать сложный проект (pet project)
