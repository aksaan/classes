# %% [markdown]
# **Домашнее задание 1**
#
# - [x] начать читать [основы Питона](https://academy.yandex.ru/handbook/python)
# > 2 главы и ~20 задач
# - [x] ознакомиться с сайтом https://leetcode.com/
# > Задачи еще не решала
# - [x] придумать простые задачки на визуализацию, статистику (pandas, matplotlib)
# > 1)график цены любого актива
# 2)население рф график
# 3)график средней заработной платы по регионам рф
# 4)график колличества безработных по регионам
# 5)смертность и рождаемость в стране
# - [ ] начать продумывать легкий проект
# - [ ] начать продумывать сложный проект (pet project)

# %% [markdown]
# решим задачки с https://pythonworld.ru/osnovy/tasks.html

# %% [markdown]
# Простейшие арифметические операции (1)
# Написать функцию arithmetic, принимающую 3 аргумента: первые 2 - числа, третий - операция, которая должна быть произведена над ними. Если третий аргумент +, сложить их; если —, то вычесть; * — умножить; / — разделить (первое на второе). В остальных случаях вернуть строку "Неизвестная операция".

# %%
def arithmetic(a, b, op):
  if op == '+':
      return a + b
  elif op == '-':
      return a - b
  elif op == '*':
      return a * b
  elif op == '/':
      return a / b
  else:
      return "Неизвестная операция"

arithmetic(2, 3, '+')
# Out:
# 5

# %% [markdown]
# Високосный год (2)
# Написать функцию is_year_leap, принимающую 1 аргумент — год, и возвращающую True, если год високосный, и False иначе.

# %%
def is_year_leap(year):
  return year % 4 == 0

is_year_leap(1988)
# Out:
# True

# %% [markdown]
# Квадрат (3)
# Написать функцию square, принимающую 1 аргумент — сторону квадрата, и возвращающую 3 значения (с помощью кортежа): периметр квадрата, площадь квадрата и диагональ квадрата.

# %%
import math
def square(a):
  p=a*4
  s=a*a
  d=math.sqrt(a**2+a**2)
  return p, s, d

square(2)
# Out:
# (8, 4, 2.8284271247461903)

# %%
import math
def square(a):
  p=a*4
  s=a*a
  d=math.sqrt(a**2+a**2)
  return p, s, d

square(2)
# Out:
# (8, 4, 2.8284271247461903)

# %%
# %%timeit
square(4)
# Out:
# 1.07 µs ± 248 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %%timeit
square2(4)
# Out:
# 321 ns ± 9.49 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# Времена года (4)
# Написать функцию season, принимающую 1 аргумент — номер месяца (от 1 до 12), и возвращающую время года, которому этот месяц принадлежит (зима, весна, лето или осень).

# %%
def season(n):
  if n==1 or n==2 or n==12:
    return "зима"
  elif n==3 or n==4 or n==5:
    return "весна"
  elif n==6 or n==7 or n==8:
    return "лето"
  elif n==9 or n==10 or n==11:
    return "осень"
  else:
    return "неправильное значение"

season(12)
# Out:
# 'зима'

# %%
def season2(n):
  if n in (1, 2, 12):
    return "зима"
  elif n in (3, 4, 5):
    return "весна"
  elif n in (6, 7, 8):
    return "лето"
  elif n in (9, 10, 11):
    return "осень"
  else:
    return "неправильное значение"

season(12)
# Out:
# 'зима'

# %%
# %%timeit
season(12)
# Out:
# 182 ns ± 55.6 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %%timeit
season2(12)
# Out:
# 151 ns ± 36.3 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %% [markdown]
# **Дома**
#
# - доделать задачки
# - выложить на гитхаб
# - дочитать хэндбук от яндекса (первые 4 главы)
# - выполнить задачи и выложить их на гитхоб
# - дописать простые задачки на визуализацию, статистику (pandas, matplotlib)
# - [ ] начать продумывать легкий проект
# - [ ] начать продумывать сложный проект (pet project)

# %% [markdown]
# Банковский вклад (5)
# Пользователь делает вклад в размере a рублей сроком на years лет под 10% годовых (каждый год размер его вклада увеличивается на 10%. Эти деньги прибавляются к сумме вклада, и на них в следующем году тоже будут проценты).
#
# Написать функцию bank, принимающая аргументы a и years, и возвращающую сумму, которая будет на счету пользователя.

# %%
def bank(a, years):
  for i in range(years):
    a = int(a+10*a/100)
  return a

bank(1000, 5)
# Out:
# 1610

# %% [markdown]
# Простые числа (6)
# Написать функцию is_prime, принимающую 1 аргумент — число от 0 до 1000, и возвращающую True, если оно простое, и False - иначе.

# %%
def is_prime(a):
  for i in range(a):
    if(a % 2 == 0):
      return "Число сложное"
    else:
      return "Число простое"

is_prime(6)
# Out:
# 'Число сложное'

# %% [markdown]
# Правильная дата (7)
# Написать функцию date, принимающую 3 аргумента — день, месяц и год. Вернуть True, если такая дата есть в нашем календаре, и False иначе.

# %%
def date(d, m, y):
  month = [31,28,31,30,31,30,31,31,30,31,30,31]
  if(y % 4 != 0) or ((y % 100 == 0) and (y % 400 == 0)):
    month[1] = 29
  if m>=1 and m<=12:
    if(d>0) and (d<=month[m-1]):
      return True
  else:
    return False

date(12, 12, 2022)
# Out:
# True

# %% [markdown]
# XOR-шифрование (8)
# Написать функцию XOR_cipher, принимающая 2 аргумента: строку, которую нужно зашифровать, и ключ шифрования, которая возвращает строку, зашифрованную путем применения функции XOR (^) над символами строки с ключом. Написать также функцию XOR_uncipher, которая по зашифрованной строке и ключу восстанавливает исходную строку.

# %%
def  XOR_cipher(st, key):
  st2 = ""
  for i in st:
    st2 = st2 +

# %%
speed1 =  int(input())
speed2 = int(input())
if speed1 > speed2:
    print("Петя")
else:
    print("Вася")

# %%
speed1 = int(input())
speed2 = int(input())
speed3 = int(input())
if(speed1>speed2) and (speed1>speed3):
    return "Петя"
if(speed2>speed3) and (speed2>speed1):
    return "Вася"
if(speed3>speed1) and (speed3>speed2):
    return "Толя"
